# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read dataset

# %%
df = pd.read_excel(r'C:\Users\User\Desktop\dspay_labelled.xlsx')
df
# Out:
#        company  title  totalyearlycompensation  yearsofexperience  \
# 0            2     11                   400000                  5
# 1            1     11                   136000                  3
# 2            2     11                   337000                  6
# 3            1     11                   222000                  4
# 4           89     11                   187000                  5
# ...        ...    ...                      ...                ...
# 21516       88     12                  1470000                  9
# 21517        2      8                  4500000                 20
# 21518       89     12                  1605000                 16
# 21519       88     12                  2372000                 22
# 21520       88      8                  4980000                 17
#
#        yearsatcompany  basesalary  stockgrantvalue   bonus  gender  Race  \
# 0                   5      210000           145000   45000       1     0
# 1                   2      124000             1000   11000       1     3
# 2                   6      177000           125000   36000       1     0
# 3                   4      164000            38000   20000       1     0
# 4                   0      165000            22000       0       1     4
# ...               ...         ...              ...     ...     ...   ...
# 21516               7      290000             1100   80000       1     0
# 21517              14      450000             3700  350000       1     0
# 21518               2      250000             1305   50000       0     4
# 21519               2      315000             1933  124000       1     1
# 21520               0      380000             4400  200000       1     0
#
#        Education       date           city  state  country
# 0              3  1/27/2020      Sunnyvale     19       63
# 1              0   7/3/2020        Redmond    161       63
# 2              0   7/3/2020      San Bruno     19       63
# 3              2   7/3/2020        Seattle    161       63
# 4              0   7/3/2020  San Francisco     19       63
# ...          ...        ...            ...    ...      ...
# 21516          0  2/15/2021     Menlo Park     19       63
# 21517          2   3/9/2021  San Francisco     19       63
# 21518          2  3/25/2021         Denver     24       63
# 21519          2  5/18/2021     Menlo Park     19       63
# 21520          2  7/30/2021     Menlo Park     19       63
#
# [21521 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21521 entries, 0 to 21520
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   company                  21521 non-null  int64
#  1   title                    21521 non-null  int64
#  2   totalyearlycompensation  21521 non-null  int64
#  3   yearsofexperience        21521 non-null  int64
#  4   yearsatcompany           21521 non-null  int64
#  5   basesalary               21521 non-null  int64
#  6   stockgrantvalue          21521 non-null  int64
#  7   bonus                    21521 non-null  int64
#  8   gender                   21521 non-null  int64
#  9   Race                     21521 non-null  int64
#  10  Education                21521 non-null  int64
#  11  date                     21521 non-null  object
#  12  city                     21521 non-null  object
#  13  state                    21521 non-null  int64
#  14  country                  21521 non-null  int64
# dtypes: int64(13), object(2)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#             company         title  totalyearlycompensation  yearsofexperience  \
# count  21521.000000  21521.000000             2.152100e+04       21521.000000
# mean      65.140700      9.508898             1.979472e+05           7.126899
# std       37.504445      3.335824             1.331233e+05           5.849500
# min        0.000000      0.000000             1.000000e+04           0.000000
# 25%       12.000000      9.000000             1.190000e+05           3.000000
# 50%       89.000000     11.000000             1.740000e+05           6.000000
# 75%       89.000000     11.000000             2.450000e+05          10.000000
# max       89.000000     14.000000             4.980000e+06          45.000000
#
#        yearsatcompany     basesalary  stockgrantvalue          bonus  \
# count    21521.000000   21521.000000     21521.000000   21521.000000
# mean         2.706566  133897.077273     44969.985270   18399.749082
# std          3.328219   57229.207611     72517.216239   24800.958541
# min          0.000000    4000.000000         0.000000       0.000000
# 25%          0.000000  100000.000000         0.000000    3000.000000
# 50%          2.000000  135000.000000     20000.000000   13000.000000
# 75%          4.000000  165000.000000     55000.000000   25000.000000
# max         40.000000  900000.000000    954000.000000  900000.000000
#
#              gender          Race     Education         state       country
# count  21521.000000  21521.000000  21521.000000  21521.000000  21521.000000
# mean       0.825240      1.658241      1.047535     81.343897     60.724223
# std        0.392052      1.867440      1.112834     57.866895      6.939999
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      0.000000     19.000000     63.000000
# 50%        1.000000      0.000000      0.000000     83.000000     63.000000
# 75%        1.000000      4.000000      2.000000    149.000000     63.000000
# max        2.000000      4.000000      4.000000    169.000000     64.000000

# %% [markdown]
# ## Drop nominal variables

# %%
df=df.drop(['date','city','stockgrantvalue'], axis=1)

# %%
df
# Out:
#        company  title  totalyearlycompensation  yearsofexperience  \
# 0            2     11                   400000                  5
# 1            1     11                   136000                  3
# 2            2     11                   337000                  6
# 3            1     11                   222000                  4
# 4           89     11                   187000                  5
# ...        ...    ...                      ...                ...
# 21516       88     12                  1470000                  9
# 21517        2      8                  4500000                 20
# 21518       89     12                  1605000                 16
# 21519       88     12                  2372000                 22
# 21520       88      8                  4980000                 17
#
#        yearsatcompany  basesalary   bonus  gender  Race  Education  state  \
# 0                   5      210000   45000       1     0          3     19
# 1                   2      124000   11000       1     3          0    161
# 2                   6      177000   36000       1     0          0     19
# 3                   4      164000   20000       1     0          2    161
# 4                   0      165000       0       1     4          0     19
# ...               ...         ...     ...     ...   ...        ...    ...
# 21516               7      290000   80000       1     0          0     19
# 21517              14      450000  350000       1     0          2     19
# 21518               2      250000   50000       0     4          2     24
# 21519               2      315000  124000       1     1          2     19
# 21520               0      380000  200000       1     0          2     19
#
#        country
# 0           63
# 1           63
# 2           63
# 3           63
# 4           63
# ...        ...
# 21516       63
# 21517       63
# 21518       63
# 21519       63
# 21520       63
#
# [21521 rows x 12 columns]

# %% [markdown]
# ## Split into training and test set
#
# Bonus as Target Variable

# %%
df1 = df.copy()

from sklearn.model_selection import train_test_split
train , test = train_test_split(df1, test_size = 0.2)

X_train = train.drop('bonus', axis=1)
y_train = train['bonus']

X_test = test.drop('bonus', axis = 1)
y_test = test['bonus']

# %% [markdown]
# ## Multi Linear Regression (MLR)

# %%
# Import module:
from sklearn.linear_model import LinearRegression
LR = LinearRegression()

# Fitting the training data
LR.fit(X_train,y_train)

# Predicting the result
y_prediction = LR.predict(X_test)

# %%
import seaborn as sns
sns.scatterplot(x=y_test, y=y_prediction, alpha=0.3)
sns.lineplot(y_test, y_test)

import matplotlib.pyplot as plt
plt.xlabel('Actual count')
plt.ylabel('Predicted count')
plt.title('Actual vs Predicted count (test set)')
plt.show()

import warnings
warnings.filterwarnings('ignore')
warnings.warn('ignore')
warnings.warn('Do not show this message')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print("Mean absolute error (linear model): {:.2f}".format(mean_absolute_error(y_test, y_prediction)))
print("Mean squared error (linear model): {:.2f}".format(mean_squared_error(y_test, y_prediction)))
print("r2_score (linear model): {:.2f}".format(r2_score(y_test, y_prediction)))
# Out:
# Mean absolute error (linear model): 10736.35
# Mean squared error (linear model): 387797250.34
# r2_score (linear model): 0.30

# %% [markdown]
# ## Random Forest

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X1_train = sc.fit_transform(X_train)
X1_test = sc.transform(X_test)

y1_train=y_train.copy()
y1_test=y_test.copy()

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(bootstrap = False, 
                                  max_depth = 100,
                                  max_features = 'sqrt',
                                  min_samples_leaf = 1,
                                  min_samples_split = 2,
                                  n_estimators = 88).fit(X1_train, y1_train)
y1_pred = regressor.predict(X1_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
print('Mean Absolute Error:', mean_absolute_error(y1_test, y1_pred).round(2))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y1_test, y1_pred)).round(2))
print("Mean squared error (linear model): {:.2f}".format(mean_squared_error(y1_test, y1_pred)))
print("r2_score (linear model): {:.2f}".format(r2_score(y1_test, y1_pred)))
# Out:
# Mean Absolute Error: 8378.42
# Root Mean Squared Error: 17162.13
# Mean squared error (linear model): 294538652.77
# r2_score (linear model): 0.47

# %% [markdown]
# ## K-Nearest Neighbour (KNN)

# %%
X2_train=X_train.copy()
X2_test=X_test.copy()
y2_train=y_train.copy()
y2_test=y_test.copy()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

x_train_scaled = scaler.fit_transform(X2_train)
X2_train = pd.DataFrame(x_train_scaled)

x_test_scaled = scaler.fit_transform(X2_test)
X2_test = pd.DataFrame(x_test_scaled)

# %%
#import required packages
from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X2_train, y_train)  #fit the model
    pred=model.predict(X2_test) #make prediction on test set
    error = sqrt(mean_squared_error(y2_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 41820.747397577514
# RMSE value for k=  2 is: 33034.24911212389
# RMSE value for k=  3 is: 29823.307251869493
# RMSE value for k=  4 is: 27100.520232351842
# RMSE value for k=  5 is: 25688.090309321116
# RMSE value for k=  6 is: 24726.397529856444
# RMSE value for k=  7 is: 24223.89030979979
# RMSE value for k=  8 is: 23815.82570491665
# RMSE value for k=  9 is: 23421.770656879467
# RMSE value for k=  10 is: 23111.584999906383
# RMSE value for k=  11 is: 23008.06715152759
# RMSE value for k=  12 is: 22756.67737203392
# RMSE value for k=  13 is: 22619.639881404637
# RMSE value for k=  14 is: 22497.894086608787
# RMSE value for k=  15 is: 22307.437318323467
# RMSE value for k=  16 is: 22206.925396576306
# RMSE value for k=  17 is: 22071.25980422902
# RMSE value for k=  18 is: 22041.757829124253
# RMSE value for k=  19 is: 21910.128875332393
# RMSE value for k=  20 is: 21863.777380042127

# %%
#plotting the rmse values against k values
curve = pd.DataFrame(rmse_val) #elbow curve 
curve.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import GridSearchCV
params = {'n_neighbors':[2,3,4,5,6,7]}

knn = neighbors.KNeighborsRegressor()

model = GridSearchCV(knn, params, cv=5)
model.fit(X2_train,y2_train)
model.best_params_
# Out:
# {'n_neighbors': 7}

# %%
y2_pred = regressor.predict(X2_test)  # test the output by changing values
y2_pred
# Out:
# array([20159.09090909, 21147.72727273, 18840.90909091, ...,
#        23488.63636364, 21352.27272727, 17954.54545455])

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score,mean_absolute_error
print("Mean ab error (linear model): {:.2f}".format(mean_absolute_error(y2_test, y2_pred)))
print("Mean squared error (linear model): {:.2f}".format(mean_squared_error(y2_test, y2_pred)))
print("r2_score (linear model): {:.2f}".format(r2_score(y2_test, y2_pred)))
#print("r2_score (linear model): {:.2f}".format(accuracy_score(y_test, y_pred)))
# Out:
# Mean ab error (linear model): 15221.28
# Mean squared error (linear model): 536098598.35
# r2_score (linear model): 0.03
