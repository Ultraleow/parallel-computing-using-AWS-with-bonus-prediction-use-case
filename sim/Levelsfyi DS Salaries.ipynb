# %%
import pandas as pd
import numpy as np
import requests
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
dspay = pd.read_csv('Levels_Fyi_Salary_Data.csv')

# %%
# remove all records with nan values
dspay = dspay.dropna()

# timestamp - remove time and keep the dates
dspay[['date','time']] = dspay['timestamp'].str.split(' ',expand=True)

# drop timestamp and time after extracting dates
dspay = dspay.drop(['timestamp',
                    'time', 
                    'level', 
                    'otherdetails', 
                    'cityid', 
                    'rowNumber', 
                    'Masters_Degree',
                    'Bachelors_Degree',
                    'Doctorate_Degree',
                    'Highschool',
                    'Some_College',
                    'Race_Asian',
                    'Race_White',
                    'Race_Two_Or_More',
                    'Race_Black',
                    'Race_Hispanic',
                    'tag',
                    'dmaid'], axis = 1)
# Out:
# Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.

# %%
# standardise company names
dspay = dspay.replace({'company' : {'Linkedin' : 'LinkedIn',
                                    'amazon' : 'Amazon',
                                    'Intel Corporation' : 'Intel',
                                    'MICROSOFT' : 'Microsoft',
                                    'linkedin' : 'LinkedIn',
                                    'facebook' : 'Facebook',
                                    'microsoft' : ' Microsoft',
                                    'AWS' : 'Amazon',
                                    'vmware' : 'VMWare',
                                    'samsung' : 'Samsung',
                                    'VMware' : 'VMWare',
                                    'capital one' : 'Capital One',
                                    'Cisco Systems' : 'Cisco',
                                    'twitter' : 'Twitter',
                                    'apple' : 'Apple',
                                    'google' : 'Google',
                                    'akamai' : 'Akamai',
                                    'Qualcomm Inc' : 'Qualcomm',
                                    'qualcomm' : 'Qualcomm',
                                    'JPMorgan Chase' : 'JP Morgan',
                                    'intel' : 'Intel',
                                    'Ernst and young' : 'EY',
                                    'Zillow Group' : 'Zillow',
                                    'Ebay' : 'eBay',
                                    'mi' : 'Mi',
                                    'TUNE' : 'Tune',
                                    'pagerduty' : 'Pagerduty',
                                    'salesforce' : 'Salesforce',
                                    'ca technologies' : 'CA Technologies',
                                    'Godaddy' : 'GoDaddy',
                                    'Visa Inc' : 'Visa',
                                    'zendesk' : 'Zendesk',
                                    'NICE' : 'Nice',
                                    'Qualcomm inc' : 'Qualcomm',
                                    'top hat' : 'Top Hat',
                                    'HPE' : 'HP',
                                    'ibm' : 'IBM',
                                    'roku' : 'Roku',
                                    'quora' : 'Quora',
                                    'BOeing' : ' Boeing',
                                    'Surveymonkey' : 'SurveyMonkey',
                                    'sony interactive entertainment' : 'Sony Interactive Entertainment',
                                    'amzon' : 'Amazon',
                                    'realtor.com' : 'Realtor.com',
                                    'Hewlett Packard Enterprise' : 'HP',
                                    'oracle' : 'Oracle',
                                    'Amzon' : 'Amazon',
                                    'airbnb' : 'Airbnb',
                                    'yelp' : 'Yelp',
                                    'houzz' : 'Houzz',
                                    'zynga' : 'Zynga',
                                    'EBAY' : 'eBay',
                                    'zillow' : 'Zillow',
                                    'APPLE' : 'Apple',
                                    'AMAZON' : 'Amazon',
                                    'Booking' : 'Booking.com',
                                    'paypal' : 'PayPal',
                                    'Samsung Research America' : 'Samsung',
                                    'servicenow' : 'ServiceNow',
                                    'Servicenow' : 'ServiceNow',
                                    'cisco systems' : 'Cisco',
                                    'Expedia Group' : 'Expedia',
                                    'athenahealth' : 'AthenaHealth',
                                    'illumina' : 'Illumina',
                                    'arista' : 'Arista',
                                    'yahoo' : 'Yahoo',
                                    'beyond limits' : 'Beyond Limits',
                                    'palo alto networks' : 'Palo Alto',
                                    'cloudera' : 'Cloudera',
                                    'uber' : 'Uber',
                                    'Akamai Technologies' : 'Akamai',
                                    'postmates' : 'Postmates',
                                    'Micron technology' : 'Micron',
                                    'Palto Alto networks' : 'Palto Alto',
                                    'wework' : 'WeWork',
                                    'kroger' : 'Kroger',
                                    'Western DIgital' : 'Western Digital',
                                    'smartsheet' : 'SmartSheet',
                                    'Smartsheet' : 'SmartSheet',
                                    'talend' : 'Talend',
                                    'veeva systems' : 'Veeva Systems',
                                    'Amazon Web Services' : 'Amazon',
                                    'Cisco Meraki' : 'Cisco',
                                    'samsara' : 'Samsara',
                                    'indeed' : 'Indeed',
                                    'loanDepot' : 'LoanDepot',
                                    'Ernst & Young' : 'EY',
                                    'homeadvisor' : 'HomeAdvisor',
                                    'mapbox' : 'Mapbox',
                                    'snapchat' : 'Snapchat',
                                    'nvidia' : 'Nvidia',
                                    'Athenahealth' : 'AthenaHealth',
                                    'discover' : 'Discover',
                                    'hpe' : 'HP',
                                    'JP Morgan Chase' : 'JP Morgan',
                                    'Samsung Electronics America' : 'Samsung',
                                    'target' : 'Target',
                                    'sap' : 'SAP',
                                    'philips' : 'Philips',
                                    'american airlines' : 'American Airlines',
                                    'JP morgan' : 'JP Morgan',
                                    'wayfair' : 'Wayfair',
                                    'Capital one' : 'Capital One',
                                    'Costco wholesale' : 'Costco Wholesale',
                                    'tesla' : 'Tesla',
                                    'AMazon' : 'Amazon',
                                    'HP Inc' : 'HP',
                                    'SONY' : 'Sony',
                                    'Cognizant Technology Solutions' : 'Cognizant',
                                    'MasterCard' : 'Mastercard',
                                    'gojek' : 'Gojek',
                                    'Aws' : 'Amazon',
                                    '3m' : '3M',
                                    'brex' : 'Brex',
                                    'fastly' : 'Fastly',
                                    'SAS Institute' : 'SAS',
                                    'Western digital' : 'Western Digital',
                                    'bosch' : 'Bosch',
                                    'GOLDMAN SACHS' : 'Goldman Sachs',
                                    'pandora' : 'Pandora',
                                    'goldman sachs' : 'Goldman Sachs',
                                    'adidas' : 'Adidas',
                                    'google llc' : 'Google',
                                    'swiggy' : 'Swiggy',
                                    'synopsys' : 'Synopsys',
                                    'CiSco' : 'Cisco',
                                    'GEICO' : 'Geico',
                                    'twitch' : 'Twitch',
                                    'Apple Inc' : 'Apple',
                                    'truckstop.com' : 'Truckstop.com',
                                    'Google LLC' : 'Google',
                                    'XING' : 'Xing',
                                    'intel corporation' : 'Intel',
                                    'lowes' : "Lowe's",
                                    'startup' : 'Startup',
                                    'SAS Software' : 'SAS',
                                    'KAYAK' : 'Kayak',
                                    'wipro' : 'Wipro',
                                    'HP INC' : 'HP',
                                    'Ibm' : 'IBM',
                                    'foursquare' : 'FourSquare',
                                    'Deloitte consulting' : 'Deloitte',
                                    'Mail.ru Group' : 'Mail.Ru Group',
                                    'Hsbc' : 'HSBC',
                                    'test' : 'Test',
                                    'Sap' : 'SAP',
                                    'Jp Morgan' : 'JP Morgan',
                                    'zapier' : 'Zapier',
                                    'FLEXE' : 'Flexe',
                                    'udaan.com' : 'Udaan.com',
                                    'Panasonic Avionics' : 'Panasonic',
                                    'dexcom' : 'Dexcom',
                                    'c3.ai' : 'C3.AI',
                                    'shutterstock' : 'ShutterStock',
                                    'Amazon web services' : 'Amazon',
                                    'coupa software' : 'Coupa Software',
                                    'national instruments' : 'National Instruments',
                                    '\xa0Googl' : 'Google',
                                    'verizon' : 'Verizon',
                                    'schlumberger' : 'Schlumberger',
                                    'jp morgan' : 'JP Morgan',
                                    'cisco' : 'Cisco',
                                    'GOogle' : 'Google',
                                    'Bosch Globl=al' : 'Bosch',
                                    'cadence design systems' : 'Cadence Design Systems',
                                    'zoominfo' : 'ZoomInfo',
                                    'Apple INc.' : 'Apple',
                                    'ebay' : 'eBay',
                                    'walmart' : 'Walmart',
                                    'autho0' : 'Autho0',
                                    'synaptics' : 'Synaptics',
                                    'amgen' : 'Amgen',
                                    'bcg' : 'BCG',
                                    'Vmware' : 'VMWare',
                                    'ORACLE' : 'Oracle',
                                    'citi' : 'Citi Bank',
                                    'microsoft corporation' : 'Microsoft',
                                    'HP inc' : 'HP',
                                    'SAS institute' : 'SAS',
                                    'applied materials' : 'Applied Materials',
                                    'wells fargo' : 'Wells Fargo',
                                    "Moody's Analytics" : "Moody's",
                                    'shopee' : 'Shopee',
                                    'seagate' : 'Seagate',
                                    'nutanix' : 'Nutanix',
                                    'wish' : 'Wish',
                                    'C3.ai' : 'C3.AI',
                                    'Deloitte Adisory' : 'Deloitte',
                                    'Databricks' : 'DataBricks',
                                    'Toyota USA' : 'Toyota',
                                    'Micron Technology' : 'Micron',
                                    'virtusa' : 'Virtusa',
                                    'Liberty Mutual' : 'Liberty Mutual Insurance',
                                    'McKinsey' : 'Mckinsey & Company',
                                    'Boston Consulting Group' : 'BCG',
                                    'Ernst and Young' : 'EY',
                                    'Tripadvisor' : 'TripAdvisor',
                                    'Mcafee' : 'McAfee',
                                    'GOJEK' : 'Gojek',
                                    'ticketmaster' : 'TicketMaster',
                                    'Walmart Labs' : 'Walmart',
                                    'NVIDIA' : 'Nvidia',
                                    'capgemini' : 'Capgemini',
                                    'Sony Interactive Entertainment' : 'Sony',
                                    'BCG Digital Ventures' : 'BCG',
                                    'PWC' : 'PwC',
                                    'Hp Inc' : 'HP',
                                    'CISCO SYSTEMS' : 'Cisco',
                                    'GE healthcare' : 'GE',
                                    'comcast' : 'ComCast',
                                    'Illumio' : 'Illumino',
                                    'Wells fargo' : 'Wells Fargo',
                                    'ocado technology' : 'Ocado Technology',
                                    'stubhub' : 'StubHub',
                                    'cvs health' : 'CVS Health',
                                    '\xa0Google' : 'Google',
                                    'tripadvisor' : 'TripAdvisor',
                                    'Citibank' : 'Citi Bank',
                                    'DISH Network' : 'Dish Network',
                                    'auth0' : 'Auth0',
                                    'Toyota Research Institute' : 'Toyota',
                                    'Strategy by PwC' : 'PwC',
                                    'JPMORGAN' : 'JP Morgan',
                                    'Microsoft Corporation' : 'Microsoft',
                                    'General Electric' : 'GE',
                                    'Here' : 'Here Technologies',
                                    'HERE Technologies' : 'Here Technologies',
                                    'Wipro Limited' : 'Wipro',
                                    ' Microsoft' : 'Microsoft',
                                    'Comcast' : 'ComCast',
                                    'Bloomberg LP' : 'Bloomberg',
                                    'Apple Inc.' : 'Apple',
                                    "Moody's analytics" : "Moody's",
                                    'Bosch Global' : 'Bosch',
                                    'Motorola Solutions' : 'Motorola',
                                    'Here' : 'Here Technologies',
                                    'SAMSUNG' : 'Samsumg',
                                    'CACI International' : 'CACI',
                                    'adobe' : 'Adobe',
                                    'airbus' : 'Airbus',
                                    'On semiconductor' : 'ON Semiconductor',
                                    'Doordash' : 'DoorDash',
                                    'Squarespace' : 'SquareSpace',
                                    'VERISIGN' : 'Verisign',
                                    'other' : 'Other',
                                    'Deloitte Consultting LLP' : 'Deloitte',
                                    'Disney Streaming Services' : 'Disney',
                                    'The Walt Disney Company' : 'Disney',
                                    'Deloitte Consulting' : 'Deloitte',
                                    'Citi' : 'Citi Bank',
                                    'Paypal' : 'PayPal',
                                    'HERE' : 'Here Technologies'}})

# %%
# break down the location by city, state, and country
dspay = dspay.join(dspay['location'].str.split(',', expand=True).rename(columns={0:'city', 1:'state', 2:'country'}))

# drop location variable
dspay = dspay.drop(['location', 3], axis = 1)

# replace null country values (assuming none values represent US)
dspay = dspay.replace({'country' : { None : 'US',
                                    ' Korea' : 'South Korea',
                                    ' Canada' : 'Canada',
                                    ' India' : 'India',
                                    ' United Kingdom' : 'United Kingdom',
                                    " Hong Kong (SAR)" : "Hong Kong (SAR)",
                                    ' China' : 'China',
                                    ' Ireland' : 'Ireland',
                                    ' Germany' : 'Germany',
                                    ' Russia' : 'Russia',
                                    ' Israel' : 'Israel',
                                    ' Singapore' : 'Singapore',
                                    ' Netherlands' : 'Netherlands',
                                    ' Argentina' : 'Argentina',
                                    ' Armenia' : 'Armenia',
                                    ' Australia' : 'Australia',
                                    ' Austria' : 'Austria'}})

# %%
dspay.to_excel('dspay.xlsx', index=False)

# %%
from sklearn import preprocessing

#Label encoder for modelling
le = preprocessing.LabelEncoder()

dspay_labelled = dspay.copy()
dspay_labelled['title'] = le.fit_transform(dspay_labelled['title'])
dspay_labelled['gender'] = le.fit_transform(dspay_labelled['gender'])
dspay_labelled['Race'] = le.fit_transform(dspay_labelled['Race'])
dspay_labelled['Education'] = le.fit_transform(dspay_labelled['Education'])
dspay_labelled['country'] = le.fit_transform(dspay_labelled['country'])

# %%
dspay_labelled
# Out:
#          company  title  totalyearlycompensation  yearsofexperience  \
# 15710     Google     11                   400000                5.0
# 23532  Microsoft     11                   136000                3.0
# 23533     Google     11                   337000                6.0
# 23534  Microsoft     11                   222000                4.0
# 23535      Blend     11                   187000                5.0
# ...          ...    ...                      ...                ...
# 61981   Facebook     12                  1470000                9.0
# 61982     Google      8                  4500000               20.0
# 61984     Zapier     12                  1605000               16.0
# 61987   Facebook     12                  2372000               22.0
# 61991   Facebook      8                  4980000               17.0
#
#        yearsatcompany  basesalary  stockgrantvalue     bonus  gender  Race  \
# 15710             5.0    210000.0         145000.0   45000.0       1     0
# 23532             2.0    124000.0           1000.0   11000.0       1     3
# 23533             6.0    177000.0         125000.0   36000.0       1     0
# 23534             4.0    164000.0          38000.0   20000.0       1     0
# 23535             0.0    165000.0          22000.0       0.0       1     4
# ...               ...         ...              ...       ...     ...   ...
# 61981             7.0    290000.0           1100.0   80000.0       1     0
# 61982            14.0    450000.0           3700.0  350000.0       1     0
# 61984             2.0    250000.0           1305.0   50000.0       0     4
# 61987             2.0    315000.0           1933.0  124000.0       1     1
# 61991             0.0    380000.0           4400.0  200000.0       1     0
#
#        Education       date           city state  country
# 15710          3  1/27/2020      Sunnyvale    CA       63
# 23532          0   7/3/2020        Redmond    WA       63
# 23533          0   7/3/2020      San Bruno    CA       63
# 23534          2   7/3/2020        Seattle    WA       63
# 23535          0   7/3/2020  San Francisco    CA       63
# ...          ...        ...            ...   ...      ...
# 61981          0  2/15/2021     Menlo Park    CA       63
# 61982          2   3/9/2021  San Francisco    CA       63
# 61984          2  3/25/2021         Denver    CO       63
# 61987          2  5/18/2021     Menlo Park    CA       63
# 61991          2  7/30/2021     Menlo Park    CA       63
#
# [21521 rows x 15 columns]

# %%
dspay_labelled['country'].nunique()
# Out:
# 65

# %%
dspay_labelled.to_excel('dspay_labelled.xlsx', index=False)
