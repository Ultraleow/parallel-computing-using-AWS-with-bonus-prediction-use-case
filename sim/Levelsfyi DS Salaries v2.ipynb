# %%
import pandas as pd
import numpy as np
import requests
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
dspay = pd.read_csv('Levels_Fyi_Salary_Data.csv')

# %%
# remove all records with nan values
dspay = dspay.dropna()

# timestamp - remove time and keep the dates
dspay[['date','time']] = dspay['timestamp'].str.split(' ',expand=True)

# drop timestamp and time after extracting dates
dspay = dspay.drop(['timestamp',
                    'time', 
                    'level', 
                    'otherdetails', 
                    'cityid', 
                    'rowNumber', 
                    'Masters_Degree',
                    'Bachelors_Degree',
                    'Doctorate_Degree',
                    'Highschool',
                    'Some_College',
                    'Race_Asian',
                    'Race_White',
                    'Race_Two_Or_More',
                    'Race_Black',
                    'Race_Hispanic',
                    'tag',
                    'dmaid'], axis = 1)

# %%
# standardise company names
dspay = dspay.replace({'company' : {'Linkedin' : 'LinkedIn',
                                    'amazon' : 'Amazon',
                                    'Intel Corporation' : 'Intel',
                                    'MICROSOFT' : 'Microsoft',
                                    'linkedin' : 'LinkedIn',
                                    'facebook' : 'Facebook',
                                    'microsoft' : ' Microsoft',
                                    'AWS' : 'Amazon',
                                    'vmware' : 'VMWare',
                                    'samsung' : 'Samsung',
                                    'VMware' : 'VMWare',
                                    'capital one' : 'Capital One',
                                    'Cisco Systems' : 'Cisco',
                                    'twitter' : 'Twitter',
                                    'apple' : 'Apple',
                                    'google' : 'Google',
                                    'akamai' : 'Akamai',
                                    'Qualcomm Inc' : 'Qualcomm',
                                    'qualcomm' : 'Qualcomm',
                                    'JPMorgan Chase' : 'JP Morgan',
                                    'intel' : 'Intel',
                                    'Ernst and young' : 'EY',
                                    'Zillow Group' : 'Zillow',
                                    'Ebay' : 'eBay',
                                    'mi' : 'Mi',
                                    'TUNE' : 'Tune',
                                    'pagerduty' : 'Pagerduty',
                                    'salesforce' : 'Salesforce',
                                    'ca technologies' : 'CA Technologies',
                                    'Godaddy' : 'GoDaddy',
                                    'Visa Inc' : 'Visa',
                                    'zendesk' : 'Zendesk',
                                    'NICE' : 'Nice',
                                    'Qualcomm inc' : 'Qualcomm',
                                    'top hat' : 'Top Hat',
                                    'HPE' : 'HP',
                                    'ibm' : 'IBM',
                                    'roku' : 'Roku',
                                    'quora' : 'Quora',
                                    'BOeing' : ' Boeing',
                                    'Surveymonkey' : 'SurveyMonkey',
                                    'sony interactive entertainment' : 'Sony Interactive Entertainment',
                                    'amzon' : 'Amazon',
                                    'realtor.com' : 'Realtor.com',
                                    'Hewlett Packard Enterprise' : 'HP',
                                    'oracle' : 'Oracle',
                                    'Amzon' : 'Amazon',
                                    'airbnb' : 'Airbnb',
                                    'yelp' : 'Yelp',
                                    'houzz' : 'Houzz',
                                    'zynga' : 'Zynga',
                                    'EBAY' : 'eBay',
                                    'zillow' : 'Zillow',
                                    'APPLE' : 'Apple',
                                    'AMAZON' : 'Amazon',
                                    'Booking' : 'Booking.com',
                                    'paypal' : 'PayPal',
                                    'Samsung Research America' : 'Samsung',
                                    'servicenow' : 'ServiceNow',
                                    'Servicenow' : 'ServiceNow',
                                    'cisco systems' : 'Cisco',
                                    'Expedia Group' : 'Expedia',
                                    'athenahealth' : 'AthenaHealth',
                                    'illumina' : 'Illumina',
                                    'arista' : 'Arista',
                                    'yahoo' : 'Yahoo',
                                    'beyond limits' : 'Beyond Limits',
                                    'palo alto networks' : 'Palo Alto Networks',
                                    'cloudera' : 'Cloudera',
                                    'uber' : 'Uber',
                                    'Akamai Technologies' : 'Akamai',
                                    'postmates' : 'Postmates',
                                    'Micron technology' : 'Micron',
                                    'Palto Alto networks' : 'Palto Alto',
                                    'wework' : 'WeWork',
                                    'kroger' : 'Kroger',
                                    'Western DIgital' : 'Western Digital',
                                    'smartsheet' : 'SmartSheet',
                                    'Smartsheet' : 'SmartSheet',
                                    'talend' : 'Talend',
                                    'veeva systems' : 'Veeva Systems',
                                    'Amazon Web Services' : 'Amazon',
                                    'Cisco Meraki' : 'Cisco',
                                    'samsara' : 'Samsara',
                                    'indeed' : 'Indeed',
                                    'loanDepot' : 'LoanDepot',
                                    'Ernst & Young' : 'EY',
                                    'homeadvisor' : 'HomeAdvisor',
                                    'mapbox' : 'Mapbox',
                                    'snapchat' : 'Snapchat',
                                    'nvidia' : 'Nvidia',
                                    'Athenahealth' : 'AthenaHealth',
                                    'discover' : 'Discover',
                                    'hpe' : 'HP',
                                    'JP Morgan Chase' : 'JP Morgan',
                                    'Samsung Electronics America' : 'Samsung',
                                    'target' : 'Target',
                                    'sap' : 'SAP',
                                    'philips' : 'Philips',
                                    'american airlines' : 'American Airlines',
                                    'JP morgan' : 'JP Morgan',
                                    'wayfair' : 'Wayfair',
                                    'Capital one' : 'Capital One',
                                    'Costco wholesale' : 'Costco Wholesale',
                                    'tesla' : 'Tesla',
                                    'AMazon' : 'Amazon',
                                    'HP Inc' : 'HP',
                                    'SONY' : 'Sony',
                                    'Cognizant Technology Solutions' : 'Cognizant',
                                    'MasterCard' : 'Mastercard',
                                    'gojek' : 'Gojek',
                                    'Aws' : 'Amazon',
                                    '3m' : '3M',
                                    'brex' : 'Brex',
                                    'fastly' : 'Fastly',
                                    'SAS Institute' : 'SAS',
                                    'Western digital' : 'Western Digital',
                                    'bosch' : 'Bosch',
                                    'GOLDMAN SACHS' : 'Goldman Sachs',
                                    'pandora' : 'Pandora',
                                    'goldman sachs' : 'Goldman Sachs',
                                    'adidas' : 'Adidas',
                                    'google llc' : 'Google',
                                    'swiggy' : 'Swiggy',
                                    'synopsys' : 'Synopsys',
                                    'CiSco' : 'Cisco',
                                    'GEICO' : 'Geico',
                                    'twitch' : 'Twitch',
                                    'Apple Inc' : 'Apple',
                                    'truckstop.com' : 'Truckstop.com',
                                    'Google LLC' : 'Google',
                                    'XING' : 'Xing',
                                    'intel corporation' : 'Intel',
                                    'lowes' : "Lowe's",
                                    'startup' : 'Startup',
                                    'SAS Software' : 'SAS',
                                    'KAYAK' : 'Kayak',
                                    'wipro' : 'Wipro',
                                    'HP INC' : 'HP',
                                    'Ibm' : 'IBM',
                                    'foursquare' : 'FourSquare',
                                    'Deloitte consulting' : 'Deloitte',
                                    'Mail.ru Group' : 'Mail.Ru Group',
                                    'Hsbc' : 'HSBC',
                                    'test' : 'Test',
                                    'Sap' : 'SAP',
                                    'Jp Morgan' : 'JP Morgan',
                                    'zapier' : 'Zapier',
                                    'FLEXE' : 'Flexe',
                                    'udaan.com' : 'Udaan.com',
                                    'Panasonic Avionics' : 'Panasonic',
                                    'dexcom' : 'Dexcom',
                                    'c3.ai' : 'C3.AI',
                                    'shutterstock' : 'ShutterStock',
                                    'Amazon web services' : 'Amazon',
                                    'coupa software' : 'Coupa Software',
                                    'national instruments' : 'National Instruments',
                                    '\xa0Googl' : 'Google',
                                    'verizon' : 'Verizon',
                                    'schlumberger' : 'Schlumberger',
                                    'jp morgan' : 'JP Morgan',
                                    'cisco' : 'Cisco',
                                    'GOogle' : 'Google',
                                    'Bosch Globl=al' : 'Bosch',
                                    'cadence design systems' : 'Cadence Design Systems',
                                    'zoominfo' : 'ZoomInfo',
                                    'Apple INc.' : 'Apple',
                                    'ebay' : 'eBay',
                                    'walmart' : 'Walmart',
                                    'autho0' : 'Autho0',
                                    'synaptics' : 'Synaptics',
                                    'amgen' : 'Amgen',
                                    'bcg' : 'BCG',
                                    'Vmware' : 'VMWare',
                                    'ORACLE' : 'Oracle',
                                    'citi' : 'Citi Bank',
                                    'microsoft corporation' : 'Microsoft',
                                    'HP inc' : 'HP',
                                    'SAS institute' : 'SAS',
                                    'applied materials' : 'Applied Materials',
                                    'wells fargo' : 'Wells Fargo',
                                    "Moody's Analytics" : "Moody's",
                                    'shopee' : 'Shopee',
                                    'seagate' : 'Seagate',
                                    'nutanix' : 'Nutanix',
                                    'wish' : 'Wish',
                                    'C3.ai' : 'C3.AI',
                                    'Deloitte Adisory' : 'Deloitte',
                                    'Databricks' : 'DataBricks',
                                    'Toyota USA' : 'Toyota',
                                    'Micron Technology' : 'Micron',
                                    'virtusa' : 'Virtusa',
                                    'Liberty Mutual' : 'Liberty Mutual Insurance',
                                    'McKinsey' : 'Mckinsey & Company',
                                    'Boston Consulting Group' : 'BCG',
                                    'Ernst and Young' : 'EY',
                                    'Tripadvisor' : 'TripAdvisor',
                                    'Mcafee' : 'McAfee',
                                    'GOJEK' : 'Gojek',
                                    'ticketmaster' : 'TicketMaster',
                                    'Walmart Labs' : 'Walmart',
                                    'NVIDIA' : 'Nvidia',
                                    'capgemini' : 'Capgemini',
                                    'Sony Interactive Entertainment' : 'Sony',
                                    'BCG Digital Ventures' : 'BCG',
                                    'PWC' : 'PwC',
                                    'Hp Inc' : 'HP',
                                    'CISCO SYSTEMS' : 'Cisco',
                                    'GE healthcare' : 'GE',
                                    'comcast' : 'ComCast',
                                    'Illumio' : 'Illumino',
                                    'Wells fargo' : 'Wells Fargo',
                                    'ocado technology' : 'Ocado Technology',
                                    'stubhub' : 'StubHub',
                                    'cvs health' : 'CVS Health',
                                    '\xa0Google' : 'Google',
                                    'tripadvisor' : 'TripAdvisor',
                                    'Citibank' : 'Citi Bank',
                                    'DISH Network' : 'Dish Network',
                                    'auth0' : 'Auth0',
                                    'Toyota Research Institute' : 'Toyota',
                                    'Strategy by PwC' : 'PwC',
                                    'JPMORGAN' : 'JP Morgan',
                                    'Microsoft Corporation' : 'Microsoft',
                                    'General Electric' : 'GE',
                                    'Here' : 'Here Technologies',
                                    'HERE Technologies' : 'Here Technologies',
                                    'Wipro Limited' : 'Wipro',
                                    ' Microsoft' : 'Microsoft',
                                    'Comcast' : 'ComCast',
                                    'Bloomberg LP' : 'Bloomberg',
                                    'Apple Inc.' : 'Apple',
                                    "Moody's analytics" : "Moody's",
                                    'Bosch Global' : 'Bosch',
                                    'Motorola Solutions' : 'Motorola',
                                    'Here' : 'Here Technologies',
                                    'SAMSUNG' : 'Samsumg',
                                    'CACI International' : 'CACI',
                                    'adobe' : 'Adobe',
                                    'airbus' : 'Airbus',
                                    'On semiconductor' : 'ON Semiconductor',
                                    'Doordash' : 'DoorDash',
                                    'Squarespace' : 'SquareSpace',
                                    'VERISIGN' : 'Verisign',
                                    'other' : 'Other',
                                    'Deloitte Consultting LLP' : 'Deloitte',
                                    'Disney Streaming Services' : 'Disney',
                                    'The Walt Disney Company' : 'Disney',
                                    'Deloitte Consulting' : 'Deloitte',
                                    'Citi' : 'Citi Bank',
                                    'Paypal' : 'PayPal',
                                    'HERE' : 'Here Technologies',
                                    'SAP Concur' : 'SAP',
                                    'Cadence' : 'Cadence Design System',
                                    'EPAM' : 'EPAM Systems',
                                    'TOAST' : 'Toast',
                                    'Procore Technologies' : 'Procore',
                                    'Coupa Software' : 'Coupa',
                                    'TELUS' : 'Telus',
                                    'EY-Parthenon' : 'EY',
                                    'Deloitte Advisory' : 'Deloitte',
                                    'Deloitte Consulting LLP' : 'Deloitte',
                                    'Hubspot' : 'HupSpot'}})

# %%
# break down the location by city, state, and country
dspay = dspay.join(dspay['location'].str.split(',', expand=True).rename(columns={0:'city', 1:'state', 2:'country'}))

# drop location variable
dspay = dspay.drop(['location', 3], axis = 1)

# replace null country values (assuming none values represent US)
dspay = dspay.replace({'country' : { None : 'US',
                                    ' Korea' : 'South Korea',
                                    ' Canada' : 'Canada',
                                    ' India' : 'India',
                                    ' United Kingdom' : 'United Kingdom',
                                    " Hong Kong (SAR)" : "Hong Kong (SAR)",
                                    ' China' : 'China',
                                    ' Ireland' : 'Ireland',
                                    ' Germany' : 'Germany',
                                    ' Russia' : 'Russia',
                                    ' Israel' : 'Israel',
                                    ' Singapore' : 'Singapore',
                                    ' Netherlands' : 'Netherlands',
                                    ' Argentina' : 'Argentina',
                                    ' Armenia' : 'Armenia',
                                    ' Australia' : 'Australia',
                                    ' Austria' : 'Austria'}})

# %%
dspay.to_excel('dspay.xlsx', index=False)

# %% [markdown]
# ### Labelling

# %%
dspay_labelled = dspay.copy()

# dspay_labelled = dspay_labelled.replace({'company' : {  'Apple' : 0,
#                                                         'Microsoft' : 1,
#                                                         'Google' : 2,
#                                                         'Oracle' : 3,
#                                                         'Adobe' : 4,
#                                                         'Salesforce' : 5,
#                                                         'IBM' : 6,
#                                                         'SAP' : 7,
#                                                         'Intuit' : 8,
#                                                         'ADP' : 9,
#                                                         'Schneider Electric' : 10,
#                                                         'ServiceNow' : 11,
#                                                         'VMWare' : 12,
#                                                         'Synopsys' : 13,
#                                                         'Dassault Systemes' : 14,
#                                                         'Snowflake' : 15,
#                                                         'Cadence Design Systems' : 16,
#                                                         'Workday' : 17,
#                                                         'Palo Alto Networks' : 18,
#                                                         'Autodesk' : 19,
#                                                         'Fortinet' : 20,
#                                                         'Atlassian' : 21,
#                                                         'Keysight' : 22,
#                                                         'Wolters Kluwer' : 23,
#                                                         'Veeva Systems' : 24,
#                                                         'Amadeus' : 25,
#                                                         'CrowdStrike' : 26,
#                                                         'DataDog' : 27,
#                                                         'The Trade Desk' : 28,
#                                                         'Ansys' : 29,
#                                                         'Zoom' : 30,
#                                                         'EPAM Systems' : 31,
#                                                         'Paycom' : 32,
#                                                         'Zscaler' : 33,
#                                                         'FICO' : 34,
#                                                         'FactSet' : 35,
#                                                         'leidos' : 36,
#                                                         'PTC' : 37,
#                                                         'Cloudflare' : 38,
#                                                         'Splunk' : 39,
#                                                         'HubSpot' : 40,
#                                                         'Akamai' : 41,
#                                                         'Tyler Technologies' : 42,
#                                                         'MongoDB' : 43,
#                                                         'SS&C Technologies' : 44,
#                                                         'Zebra Technologies' : 45,
#                                                         'Palantir' : 46,
#                                                         'NetApp' : 47,
#                                                         'Nice' : 48,
#                                                         'Trimble' : 49,
#                                                         'Zoominfo' : 50,
#                                                         'Amdocs' : 51,
#                                                         'Dynatrace' : 52,
#                                                         'Unity Technologies' : 53,
#                                                         'DocuSign' : 54,
#                                                         'Paylocity' : 55,
#                                                         'Okta' : 56,
#                                                         'Zendesk' : 57,
#                                                         'Ceridian' : 58,
#                                                         'Sage' : 59,
#                                                         'Toast' : 60,
#                                                         'Genpact' : 61,
#                                                         'F5 Networks' : 62,
#                                                         'Twilio' : 63,
#                                                         'Dropbox' : 64,
#                                                         'OpenText' : 65,
#                                                         'Xero' : 66,
#                                                         'Globant' : 67,
#                                                         'UiPath' : 68,
#                                                         'Trend Micro' : 69,
#                                                         'GitLab' : 70,
#                                                         'Procore' : 71,
#                                                         'Coupa' : 72,
#                                                         'Confluent' : 73,
#                                                         'Samsara' : 74,
#                                                         'Nutanix' : 75,
#                                                         'Qualtrics' : 76,
#                                                         'Clearwater Analytics' : 77,
#                                                         'Telus' : 78,
#                                                         'SmartSheet' : 79,
#                                                         'HashiCorp' : 80,
#                                                         'KPMG' : 81,
#                                                         'EY' : 82,
#                                                         'PwC' : 83,
#                                                         'Deloitte' : 84,
#                                                         'BCG' : 85,
#                                                         'Mckinsey & Company' : 86,
#                                                         'Goldman Sachs' : 87,
#                                                         'Facebook' : 88}})

# %%
# dspay_labelled.loc[dspay_labelled["company"] != 'Apple', 'Microsoft', 'Google', 'Oracle', 'Salesforce','IBM', 'Intuit', 
#                    'SAP', 'ADP', 'Schneider Electric', 'ServiceNow', 'VMWare','Synopsys', 'Dassault Systemes', 'Snowflake', 
#                    'Cadence Design Systems','Workday', 'Palo Alto Networks', 'Autodesk', 'Fortinet', 'Atlassian',
#                    'Keysight', 'Wolters Kluwer', 'Veeva Systems', 'Amadeus', 'CrowdStrike', 'DataDog', 'The Trade Desk',
#                    'Ansys', 'Zoom', 'EPAM Systems', 'Paycom', 'Zscaler', 'FICO', 'FactSet', 'leidos', 'PTC', 'Cloudflare',
#                    'Splunk', 'HubSpot', 'Akamai', 'Tyler Technologies', 'MongoDB', 'SS&C Technologies', 'Zebra Technologies',
#                    'Palantir', 'NetApp', 'Nice', 'Trimble', 'Zoominfo', 'Amdocs', 'Dynatrace', 'Unity Technologies',
#                    'DocuSign', 'Paylocity', 'Okta', 'Zendesk', 'Ceridian', 'Sage', 'Toast', 'Genpact', 'F5 Networks',
#                    'Twilio', 'Dropbox', 'OpenText', 'Xero', 'Globant', 'UiPath', 'Trend Micro', 'GitLab', 'Procore',
#                    'Coupa', 'Confluent', 'Samsara', 'Nutanix', 'Qualtrics', 'Clearwater Analytics', 'Telus', 'SmartSheet',
#                    'HashiCorp', 'KPMG', 'EY', 'PwC', 'Deloitte', 'BCG', 'Mackinsey & Company', 'Goldman Sachs',
#                    'Facebook'] = 89

# %%
dspay_labelled['company'] = dspay_labelled['company'].map({ 'Apple' : 0,
                                                            'Microsoft' : 1,
                                                            'Google' : 2,
                                                            'Oracle' : 3,
                                                            'Adobe' : 4,
                                                            'Salesforce' : 5,
                                                            'IBM' : 6,
                                                            'SAP' : 7,
                                                            'Intuit' : 8,
                                                            'ADP' : 9,
                                                            'Schneider Electric' : 10,
                                                            'ServiceNow' : 11,
                                                            'VMWare' : 12,
                                                            'Synopsys' : 13,
                                                            'Dassault Systemes' : 14,
                                                            'Snowflake' : 15,
                                                            'Cadence Design Systems' : 16,
                                                            'Workday' : 17,
                                                            'Palo Alto Networks' : 18,
                                                            'Autodesk' : 19,
                                                            'Fortinet' : 20,
                                                            'Atlassian' : 21,
                                                            'Keysight' : 22,
                                                            'Wolters Kluwer' : 23,
                                                            'Veeva Systems' : 24,
                                                            'Amadeus' : 25,
                                                            'CrowdStrike' : 26,
                                                            'DataDog' : 27,
                                                            'The Trade Desk' : 28,
                                                            'Ansys' : 29,
                                                            'Zoom' : 30,
                                                            'EPAM Systems' : 31,
                                                            'Paycom' : 32,
                                                            'Zscaler' : 33,
                                                            'FICO' : 34,
                                                            'FactSet' : 35,
                                                            'leidos' : 36,
                                                            'PTC' : 37,
                                                            'Cloudflare' : 38,
                                                            'Splunk' : 39,
                                                            'HubSpot' : 40,
                                                            'Akamai' : 41,
                                                            'Tyler Technologies' : 42,
                                                            'MongoDB' : 43,
                                                            'SS&C Technologies' : 44,
                                                            'Zebra Technologies' : 45,
                                                            'Palantir' : 46,
                                                            'NetApp' : 47,
                                                            'Nice' : 48,
                                                            'Trimble' : 49,
                                                            'Zoominfo' : 50,
                                                            'Amdocs' : 51,
                                                            'Dynatrace' : 52,
                                                            'Unity Technologies' : 53,
                                                            'DocuSign' : 54,
                                                            'Paylocity' : 55,
                                                            'Okta' : 56,
                                                            'Zendesk' : 57,
                                                            'Ceridian' : 58,
                                                            'Sage' : 59,
                                                            'Toast' : 60,
                                                            'Genpact' : 61,
                                                            'F5 Networks' : 62,
                                                            'Twilio' : 63,
                                                            'Dropbox' : 64,
                                                            'OpenText' : 65,
                                                            'Xero' : 66,
                                                            'Globant' : 67,
                                                            'UiPath' : 68,
                                                            'Trend Micro' : 69,
                                                            'GitLab' : 70,
                                                            'Procore' : 71,
                                                            'Coupa' : 72,
                                                            'Confluent' : 73,
                                                            'Samsara' : 74,
                                                            'Nutanix' : 75,
                                                            'Qualtrics' : 76,
                                                            'Clearwater Analytics' : 77,
                                                            'Telus' : 78,
                                                            'SmartSheet' : 79,
                                                            'HashiCorp' : 80,
                                                            'KPMG' : 81,
                                                            'EY' : 82,
                                                            'PwC' : 83,
                                                            'Deloitte' : 84,
                                                            'BCG' : 85,
                                                            'Mckinsey & Company' : 86,
                                                            'Goldman Sachs' : 87,
                                                            'Facebook' : 88}).fillna(89)

# %%
dspay_labelled
# Out:
#        company                         title  totalyearlycompensation  \
# 15710      2.0             Software Engineer                   400000
# 23532      1.0             Software Engineer                   136000
# 23533      2.0             Software Engineer                   337000
# 23534      1.0             Software Engineer                   222000
# 23535     89.0             Software Engineer                   187000
# ...        ...                           ...                      ...
# 61981     88.0  Software Engineering Manager                  1470000
# 61982      2.0               Product Manager                  4500000
# 61984     89.0  Software Engineering Manager                  1605000
# 61987     88.0  Software Engineering Manager                  2372000
# 61991     88.0               Product Manager                  4980000
#
#        yearsofexperience  yearsatcompany  basesalary  stockgrantvalue  \
# ...

# %%
from sklearn import preprocessing

#Label encoder for modelling
le = preprocessing.LabelEncoder()


dspay_labelled['title'] = le.fit_transform(dspay_labelled['title'])
dspay_labelled['gender'] = le.fit_transform(dspay_labelled['gender'])
dspay_labelled['Race'] = le.fit_transform(dspay_labelled['Race'])
dspay_labelled['Education'] = le.fit_transform(dspay_labelled['Education'])
dspay_labelled['country'] = le.fit_transform(dspay_labelled['country'])
dspay_labelled['state'] = le.fit_transform(dspay_labelled['state'])

# %%
dspay_labelled
# Out:
#        company  title  totalyearlycompensation  yearsofexperience  \
# 15710      2.0     11                   400000                5.0
# 23532      1.0     11                   136000                3.0
# 23533      2.0     11                   337000                6.0
# 23534      1.0     11                   222000                4.0
# 23535     89.0     11                   187000                5.0
# ...        ...    ...                      ...                ...
# 61981     88.0     12                  1470000                9.0
# 61982      2.0      8                  4500000               20.0
# 61984     89.0     12                  1605000               16.0
# 61987     88.0     12                  2372000               22.0
# 61991     88.0      8                  4980000               17.0
#
#        yearsatcompany  basesalary  stockgrantvalue     bonus  gender  Race  \
# 15710             5.0    210000.0         145000.0   45000.0       1     0
# ...

# %%
dspay_labelled.to_excel('dspay_labelled.xlsx', index=False)
